# %%
import pandas as pd

# %%
#df = pd.read_csv('data/Building_Energy_Benchmarks.csv')
df = pd.read_csv('https://opendata.arcgis.com/datasets/aba010cff7fe4d4cb369a54b56cd7544_45.csv')
df.to_csv('Building_Energy_Benchmarks.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#            X          Y  OBJECTID          PID DCREALPROPERTYID  PMPROPERTYID  \
# 0 -77.039745  38.895862         1    PM4373175        0171_0814     4373175.0
# 1 -77.016460  38.900567         2  DC0516S0036       0516S_0036           NaN
# 2 -77.037746  38.906498         3   DC01820082        0182_0082           NaN
# 3 -77.031592  38.902935         4    PM1331555        0248_0812     1331555.0
# 4 -77.043072  38.906668         5    PM3299991        0139_0817     3299991.0
#
#                              PROPERTYNAME  PMPARENTPROPERTYID  \
# 0  Corcoran School of the Arts and Design                 NaN
# 1                                     NaN                 NaN
# 2                                     NaN                 NaN
# 3             Hamilton Crowne Plaza Hotel                 NaN
# 4           Jefferson Bldg - DC Reporting                 NaN
#
#   PARENTPROPERTYNAME  REPORTINGYEAR  ... ELECTRICITYUSE_KBTU_MARCH  \
# ...

# %%
df.shape
# Out:
# (15731, 71)

# %%
df.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'PID', 'DCREALPROPERTYID', 'PMPROPERTYID',
#        'PROPERTYNAME', 'PMPARENTPROPERTYID', 'PARENTPROPERTYNAME',
#        'REPORTINGYEAR', 'REPORTSTATUS', 'ADDRESSOFRECORD', 'OWNEROFRECORD',
#        'WARD', 'REPORTEDADDRESS', 'CITY', 'STATE', 'POSTALCODE', 'YEARBUILT',
#        'PRIMARYPROPERTYTYPE_SELFSELECT', 'PRIMARYPROPERTYTYPE_EPACALC',
#        'TAXRECORDFLOORAREA', 'REPORTEDBUILDINGGROSSFLOORAREA',
#        'ENERGYSTARSCORE', 'SITEEUI_KBTU_FT', 'WEATHERNORMALZEDSITEEUI_KBTUFT',
#        'SOURCEEUI_KBTU_FT', 'WEATHERNORMALZEDSOUREUI_KBTUFT',
#        'TOTGHGEMISSIONS_METRICTONSCO2E', 'TOTGHGEMISSINTENSITY_KGCO2EFT',
#        'WATERSCORE_MFPROPERTIES', 'WATERUSE_ALLWATERSOURCES_KGAL',
#        'NATURALGASUSE_THERMS', 'FUELOILANDDIESELFUELUSEKBTU',
#        'METEREDAREAS_ENERGY', 'METEREDAREAS_WATER', 'LATITUDE', 'LONGITUDE',
#        'ADDRESSID', 'XCOORD', 'YCOORD', 'GIS_LAST_MOD_DTTM',
# ...

# %%
df.isnull().sum()
# Out:
# X                                   0
# Y                                   0
# OBJECTID                            0
# PID                                 0
# DCREALPROPERTYID                    0
#                                  ...
# ELECTRICITYUSE_KBTU_AUGUST       2757
# ELECTRICITYUSE_KBTU_SEPTEMBER    2757
# ELECTRICITYUSE_KBTU_OCTOBER      2757
# ELECTRICITYUSE_KBTU_NOVEMBER     2757
# ELECTRICITYUSE_KBTU_DECEMBER     2757
# Length: 71, dtype: int64

# %%
df[df.duplicated(subset=['PID'])]
# Out:
#                X          Y  OBJECTID        PID DCREALPROPERTYID  \
# 194   -77.052938  38.928033       195  PM3984805        2210_0001
# 202   -77.018677  38.885585       203  PM1878470        0493_0806
# 204   -77.054320  38.928990       205  PM4260407        2210_0006
# 217   -76.997012  38.847807       218  PM4780156        5982_0815
# 224   -77.037048  38.931027       225  PM3541282        2608_1039
# ...          ...        ...       ...        ...              ...
# 15726 -77.021657  38.907957     15727  PM3858763        0447_0039
# 15727 -77.002476  38.919533     15728  PM4380823        3560_0001
# 15728 -76.994290  38.922150     15729  PM4822871        3846_0085
# 15729 -76.998195  38.928182     15730  PM4373562        3648_0915
# 15730 -77.053795  38.928391     15731  PM3984618        2210_0010
#
#        PMPROPERTYID                              PROPERTYNAME  \
# 194       3984805.0                    2301 Connecticut Plaza
# ...

# %%
df[df.duplicated(subset=['PID', 'REPORTINGYEAR'])]
# Out:
# Empty DataFrame
# ...

# %%
def buildings_with_12_month_elec_data(integer):
    reportingyear_counts = df.groupby(['PID'])['REPORTINGYEAR'].count().reset_index(name='Count')

# %%
def buildings_with_12_month_elec_data(integer):
    reportingyear_counts = df.groupby(['PID'])['REPORTINGYEAR'].count().reset_index(name='Count')
    return reportingyear_counts[reportingyear_counts['Count'] >= integer].sort_values(by=['Count'], ascending=False)

# %%
reportingyear_counts = 1

# %%
twelve_months_elec = df[(df['ELECTRICITYUSE_KBTU_JANUARY']>0) & (df['ELECTRICITYUSE_KBTU_FEBRUARY']>0) & (df['ELECTRICITYUSE_KBTU_MARCH']>0) & (df['ELECTRICITYUSE_KBTU_APRIL']>0) & (df['ELECTRICITYUSE_KBTU_MAY']>0) & (df['ELECTRICITYUSE_KBTU_JUNE']>0) & (df['ELECTRICITYUSE_KBTU_JULY']>0) & (df['ELECTRICITYUSE_KBTU_AUGUST']>0) & (df['ELECTRICITYUSE_KBTU_SEPTEMBER']>0) & (df['ELECTRICITYUSE_KBTU_OCTOBER']>0) & (df['ELECTRICITYUSE_KBTU_NOVEMBER']>0) & (df['ELECTRICITYUSE_KBTU_DECEMBER']>0)]

# %%
print(twelve_months_elec)
# Out:
#                X          Y  OBJECTID        PID DCREALPROPERTYID  \
# 842   -77.036056  38.905370       843  PM1034322        0197_0853
# 843   -77.034300  38.903406       844  PM3989907        0216_0035
# 844   -77.060623  38.902852       845  PM2590129        1190_0078
# 845   -77.083097  38.935100       846  PM4007835        1601_2421
# 846   -77.029996  38.900581       847  PM1435721        0250_0047
# ...          ...        ...       ...        ...              ...
# 13715 -77.042188  38.904504     13716  PM3019499        0140_0094
# 13716 -76.999957  38.826194     13717  PM4370572        6242_0834
# 13717 -76.997823  38.900024     13718  PM3262071        0859_0837
# 13718 -77.038891  38.909201     13719  PM3495624        0157_0867
# 13719 -77.051747  38.899099     13720  PM3509928        0031_0835
#
#        PMPROPERTYID                                 PROPERTYNAME  \
# 842       1034322.0     American Chemical Society - Headquarters
# ...

# %%
tme_energy_star = df[(df['ELECTRICITYUSE_KBTU_JANUARY']>0) & (df['ELECTRICITYUSE_KBTU_FEBRUARY']>0) & (df['ELECTRICITYUSE_KBTU_MARCH']>0) & (df['ELECTRICITYUSE_KBTU_APRIL']>0) & (df['ELECTRICITYUSE_KBTU_MAY']>0) & (df['ELECTRICITYUSE_KBTU_JUNE']>0) & (df['ELECTRICITYUSE_KBTU_JULY']>0) & (df['ELECTRICITYUSE_KBTU_AUGUST']>0) & (df['ELECTRICITYUSE_KBTU_SEPTEMBER']>0) & (df['ELECTRICITYUSE_KBTU_OCTOBER']>0) & (df['ELECTRICITYUSE_KBTU_NOVEMBER']>0) & (df['ELECTRICITYUSE_KBTU_DECEMBER']>0) & (df['ENERGYSTARSCORE']>0)]

# %%
print(tme_energy_star)
# Out:
#                X          Y  OBJECTID        PID DCREALPROPERTYID  \
# 842   -77.036056  38.905370       843  PM1034322        0197_0853
# 843   -77.034300  38.903406       844  PM3989907        0216_0035
# 844   -77.060623  38.902852       845  PM2590129        1190_0078
# 845   -77.083097  38.935100       846  PM4007835        1601_2421
# 846   -77.029996  38.900581       847  PM1435721        0250_0047
# ...          ...        ...       ...        ...              ...
# 13715 -77.042188  38.904504     13716  PM3019499        0140_0094
# 13716 -76.999957  38.826194     13717  PM4370572        6242_0834
# 13717 -76.997823  38.900024     13718  PM3262071        0859_0837
# 13718 -77.038891  38.909201     13719  PM3495624        0157_0867
# 13719 -77.051747  38.899099     13720  PM3509928        0031_0835
#
#        PMPROPERTYID                                 PROPERTYNAME  \
# 842       1034322.0     American Chemical Society - Headquarters
# ...

# %%
tmeess_ghg = df[(df['ELECTRICITYUSE_KBTU_JANUARY']>0) & (df['ELECTRICITYUSE_KBTU_FEBRUARY']>0) & (df['ELECTRICITYUSE_KBTU_MARCH']>0) & (df['ELECTRICITYUSE_KBTU_APRIL']>0) & (df['ELECTRICITYUSE_KBTU_MAY']>0) & (df['ELECTRICITYUSE_KBTU_JUNE']>0) & (df['ELECTRICITYUSE_KBTU_JULY']>0) & (df['ELECTRICITYUSE_KBTU_AUGUST']>0) & (df['ELECTRICITYUSE_KBTU_SEPTEMBER']>0) & (df['ELECTRICITYUSE_KBTU_OCTOBER']>0) & (df['ELECTRICITYUSE_KBTU_NOVEMBER']>0) & (df['ELECTRICITYUSE_KBTU_DECEMBER']>0) & (df['ENERGYSTARSCORE']>0) & (df['TOTGHGEMISSIONS_METRICTONSCO2E']>0)]

# %%
print(tmeess_ghg)
# Out:
#                X          Y  OBJECTID        PID DCREALPROPERTYID  \
# 842   -77.036056  38.905370       843  PM1034322        0197_0853
# 843   -77.034300  38.903406       844  PM3989907        0216_0035
# 844   -77.060623  38.902852       845  PM2590129        1190_0078
# 845   -77.083097  38.935100       846  PM4007835        1601_2421
# 846   -77.029996  38.900581       847  PM1435721        0250_0047
# ...          ...        ...       ...        ...              ...
# 13715 -77.042188  38.904504     13716  PM3019499        0140_0094
# 13716 -76.999957  38.826194     13717  PM4370572        6242_0834
# 13717 -76.997823  38.900024     13718  PM3262071        0859_0837
# 13718 -77.038891  38.909201     13719  PM3495624        0157_0867
# 13719 -77.051747  38.899099     13720  PM3509928        0031_0835
#
#        PMPROPERTYID                                 PROPERTYNAME  \
# 842       1034322.0     American Chemical Society - Headquarters
# ...

# %%
 tmeessghg_water = df[(df['ELECTRICITYUSE_KBTU_JANUARY']>0) & (df['ELECTRICITYUSE_KBTU_FEBRUARY']>0) & (df['ELECTRICITYUSE_KBTU_MARCH']>0) & (df['ELECTRICITYUSE_KBTU_APRIL']>0) & (df['ELECTRICITYUSE_KBTU_MAY']>0) & (df['ELECTRICITYUSE_KBTU_JUNE']>0) & (df['ELECTRICITYUSE_KBTU_JULY']>0) & (df['ELECTRICITYUSE_KBTU_AUGUST']>0) & (df['ELECTRICITYUSE_KBTU_SEPTEMBER']>0) & (df['ELECTRICITYUSE_KBTU_OCTOBER']>0) & (df['ELECTRICITYUSE_KBTU_NOVEMBER']>0) & (df['ELECTRICITYUSE_KBTU_DECEMBER']>0) & (df['ENERGYSTARSCORE']>0) & (df['TOTGHGEMISSIONS_METRICTONSCO2E']>0) & (df['WATERUSE_ALLWATERSOURCES_KGAL']>0)]

# %%
print(tmeessghg_water)
# Out:
#                X          Y  OBJECTID        PID DCREALPROPERTYID  \
# 842   -77.036056  38.905370       843  PM1034322        0197_0853
# 843   -77.034300  38.903406       844  PM3989907        0216_0035
# 844   -77.060623  38.902852       845  PM2590129        1190_0078
# 845   -77.083097  38.935100       846  PM4007835        1601_2421
# 846   -77.029996  38.900581       847  PM1435721        0250_0047
# ...          ...        ...       ...        ...              ...
# 13715 -77.042188  38.904504     13716  PM3019499        0140_0094
# 13716 -76.999957  38.826194     13717  PM4370572        6242_0834
# 13717 -76.997823  38.900024     13718  PM3262071        0859_0837
# 13718 -77.038891  38.909201     13719  PM3495624        0157_0867
# 13719 -77.051747  38.899099     13720  PM3509928        0031_0835
#
#        PMPROPERTYID                                 PROPERTYNAME  \
# 842       1034322.0     American Chemical Society - Headquarters
# ...

# %%
tmeessghg_water_2019 = df[(df['ELECTRICITYUSE_KBTU_JANUARY']>0) & (df['ELECTRICITYUSE_KBTU_FEBRUARY']>0) & (df['ELECTRICITYUSE_KBTU_MARCH']>0) & (df['ELECTRICITYUSE_KBTU_APRIL']>0) & (df['ELECTRICITYUSE_KBTU_MAY']>0) & (df['ELECTRICITYUSE_KBTU_JUNE']>0) & (df['ELECTRICITYUSE_KBTU_JULY']>0) & (df['ELECTRICITYUSE_KBTU_AUGUST']>0) & (df['ELECTRICITYUSE_KBTU_SEPTEMBER']>0) & (df['ELECTRICITYUSE_KBTU_OCTOBER']>0) & (df['ELECTRICITYUSE_KBTU_NOVEMBER']>0) & (df['ELECTRICITYUSE_KBTU_DECEMBER']>0) & (df['ENERGYSTARSCORE']>0) & (df['TOTGHGEMISSIONS_METRICTONSCO2E']>0) & (df['WATERUSE_ALLWATERSOURCES_KGAL']>0) & (df['REPORTINGYEAR']==2019)]

# %%
print(tmeessghg_water_2019)
# Out:
#                X          Y  OBJECTID        PID DCREALPROPERTYID  \
# 2061  -77.025362  38.884668      2062  PM3353545        0387_0871
# 2063  -77.042464  38.903563      2064  PM1159361        0107_0075
# 2064  -77.017406  38.904111      2065  PM4005952       0515N_0866
# 2065  -77.036081  38.932907      2066  PM3072203        2677_0811
# 2066  -77.007182  38.901560      2067  PM2609487        0675_0846
# ...          ...        ...       ...        ...              ...
# 13449 -77.003214  38.899211     13450  PM4536856        0752_0862
# 13450 -77.014118  38.879698     13451  PM3295814        0540_0118
# 13451 -77.040597  38.900501     13452  PM2256973        0127_0843
# 13452 -76.995457  38.885047     13453  PM6242984        0901_0804
# 13454 -77.088451  38.921197     13455  PM4768216        1341_0861
#
#        PMPROPERTYID                      PROPERTYNAME  PMPARENTPROPERTYID  \
# 2061      3353545.0            L Enfant Plaza - North                 NaN
# ...

# %%
tmeessghg_water_2019.count()
# Out:
# X                                1336
# Y                                1336
# OBJECTID                         1336
# PID                              1336
# DCREALPROPERTYID                 1336
#                                  ...
# ELECTRICITYUSE_KBTU_AUGUST       1336
# ELECTRICITYUSE_KBTU_SEPTEMBER    1336
# ELECTRICITYUSE_KBTU_OCTOBER      1336
# ELECTRICITYUSE_KBTU_NOVEMBER     1336
# ELECTRICITYUSE_KBTU_DECEMBER     1336
# Length: 71, dtype: int64

# %%
tmeessghg_water_2018 = df[(df['ELECTRICITYUSE_KBTU_JANUARY']>0) & (df['ELECTRICITYUSE_KBTU_FEBRUARY']>0) & (df['ELECTRICITYUSE_KBTU_MARCH']>0) & (df['ELECTRICITYUSE_KBTU_APRIL']>0) & (df['ELECTRICITYUSE_KBTU_MAY']>0) & (df['ELECTRICITYUSE_KBTU_JUNE']>0) & (df['ELECTRICITYUSE_KBTU_JULY']>0) & (df['ELECTRICITYUSE_KBTU_AUGUST']>0) & (df['ELECTRICITYUSE_KBTU_SEPTEMBER']>0) & (df['ELECTRICITYUSE_KBTU_OCTOBER']>0) & (df['ELECTRICITYUSE_KBTU_NOVEMBER']>0) & (df['ELECTRICITYUSE_KBTU_DECEMBER']>0) & (df['ENERGYSTARSCORE']>0) & (df['TOTGHGEMISSIONS_METRICTONSCO2E']>0) & (df['WATERUSE_ALLWATERSOURCES_KGAL']>0) & (df['REPORTINGYEAR']==2018)]

# %%
tmeessghg_water_2018.count()
# Out:
# X                                1292
# Y                                1292
# OBJECTID                         1292
# PID                              1292
# DCREALPROPERTYID                 1292
#                                  ...
# ELECTRICITYUSE_KBTU_AUGUST       1292
# ELECTRICITYUSE_KBTU_SEPTEMBER    1292
# ELECTRICITYUSE_KBTU_OCTOBER      1292
# ELECTRICITYUSE_KBTU_NOVEMBER     1292
# ELECTRICITYUSE_KBTU_DECEMBER     1292
# Length: 71, dtype: int64

# %%
tmeessghg_water_2017 = df[(df['ELECTRICITYUSE_KBTU_JANUARY']>0) & (df['ELECTRICITYUSE_KBTU_FEBRUARY']>0) & (df['ELECTRICITYUSE_KBTU_MARCH']>0) & (df['ELECTRICITYUSE_KBTU_APRIL']>0) & (df['ELECTRICITYUSE_KBTU_MAY']>0) & (df['ELECTRICITYUSE_KBTU_JUNE']>0) & (df['ELECTRICITYUSE_KBTU_JULY']>0) & (df['ELECTRICITYUSE_KBTU_AUGUST']>0) & (df['ELECTRICITYUSE_KBTU_SEPTEMBER']>0) & (df['ELECTRICITYUSE_KBTU_OCTOBER']>0) & (df['ELECTRICITYUSE_KBTU_NOVEMBER']>0) & (df['ELECTRICITYUSE_KBTU_DECEMBER']>0) & (df['ENERGYSTARSCORE']>0) & (df['TOTGHGEMISSIONS_METRICTONSCO2E']>0) & (df['WATERUSE_ALLWATERSOURCES_KGAL']>0) & (df['REPORTINGYEAR']==2017)]

# %%
tmeessghg_water_2017.count()
# Out:
# X                                0
# Y                                0
# OBJECTID                         0
# PID                              0
# DCREALPROPERTYID                 0
#                                 ..
# ELECTRICITYUSE_KBTU_AUGUST       0
# ELECTRICITYUSE_KBTU_SEPTEMBER    0
# ELECTRICITYUSE_KBTU_OCTOBER      0
# ELECTRICITYUSE_KBTU_NOVEMBER     0
# ELECTRICITYUSE_KBTU_DECEMBER     0
# Length: 71, dtype: int64

# %%
tmeessghgwatng_2019 = df[(df['ELECTRICITYUSE_KBTU_JANUARY']>0) & (df['ELECTRICITYUSE_KBTU_FEBRUARY']>0) & (df['ELECTRICITYUSE_KBTU_MARCH']>0) & (df['ELECTRICITYUSE_KBTU_APRIL']>0) & (df['ELECTRICITYUSE_KBTU_MAY']>0) & (df['ELECTRICITYUSE_KBTU_JUNE']>0) & (df['ELECTRICITYUSE_KBTU_JULY']>0) & (df['ELECTRICITYUSE_KBTU_AUGUST']>0) & (df['ELECTRICITYUSE_KBTU_SEPTEMBER']>0) & (df['ELECTRICITYUSE_KBTU_OCTOBER']>0) & (df['ELECTRICITYUSE_KBTU_NOVEMBER']>0) & (df['ELECTRICITYUSE_KBTU_DECEMBER']>0) & (df['ENERGYSTARSCORE']>0) & (df['TOTGHGEMISSIONS_METRICTONSCO2E']>0) & (df['WATERUSE_ALLWATERSOURCES_KGAL']>0) & (df['REPORTINGYEAR']==2019) & (df['NATURALGAS_KBTU_JANUARY']>0) & (df['NATURALGAS_KBTU_FEBRUARY']>0) & (df['NATURALGAS_KBTU_MARCH']>0) & (df['NATURALGAS_KBTU_APRIL']>0) & (df['NATURALGAS_KBTU_MAY']>0) & (df['NATURALGAS_KBTU_JUNE']>0) & (df['NATURALGAS_KBTU_JULY']>0) & (df['NATURALGAS_KBTU_AUGUST']>0) & (df['NATURALGAS_KBTU_SEPTEMBER']>0) & (df['NATURALGAS_KBTU_OCTOBER']>0) & (df['NATURALGAS_KBTU_NOVEMBER']>0) & (df['NATURALGAS_KBTU_DECEMBER']>0)]

# %%
tmeessghgwatng_2019.count()
# Out:
# X                                904
# Y                                904
# OBJECTID                         904
# PID                              904
# DCREALPROPERTYID                 904
#                                 ...
# ELECTRICITYUSE_KBTU_AUGUST       904
# ELECTRICITYUSE_KBTU_SEPTEMBER    904
# ELECTRICITYUSE_KBTU_OCTOBER      904
# ELECTRICITYUSE_KBTU_NOVEMBER     904
# ELECTRICITYUSE_KBTU_DECEMBER     904
# Length: 71, dtype: int64

# %%
group_year = df.groupby("REPORTINGYEAR").count()

# %%
print(group_year)
#This portrays the how robust reporting is in a given year.  The data shows that reporting numbers grow in later years - especially in 2018 and 2019.
# Out:
#                   X     Y  OBJECTID   PID  DCREALPROPERTYID  PMPROPERTYID  \
# REPORTINGYEAR
# 2010            948   948       948   948               948            91
# 2011            905   905       905   905               905           760
# 2012           1083  1083      1083  1083              1083           894
# 2013           1595  1595      1595  1595              1595          1363
# 2014           1711  1711      1711  1711              1711          1425
# 2015           1690  1690      1690  1690              1690          1479
# 2016           1705  1705      1705  1705              1705          1497
# 2017           1739  1739      1739  1739              1739          1582
# 2018           2218  2218      2218  2218              2218          1963
# 2019           2137  2137      2137  2137              2137          1861
#
#                PROPERTYNAME  PMPARENTPROPERTYID  PARENTPROPERTYNAME  \
# REPORTINGYEAR
# ...

# %%
#This counts instances across variables grouped by reporting year and property type.
df.groupby(["REPORTINGYEAR","PRIMARYPROPERTYTYPE_SELFSELECT"]).count()
# Out:
#                                                       X   Y  OBJECTID  PID  \
# REPORTINGYEAR PRIMARYPROPERTYTYPE_SELFSELECT
# 2010          College/University                     10  10        10   10
#               College/University (Campus-Level)       4   4         4    4
#               Hospital (General Medical & Surgical)   1   1         1    1
#               Mixed Use Property                      1   1         1    1
#               Multifamily Housing                    15  15        15   15
# ...                                                  ..  ..       ...  ...
# 2019          Supermarket/Grocery Store              15  15        15   15
#               Urgent Care/Clinic/Other Outpatient     2   2         2    2
#               Wastewater Treatment Plant              1   1         1    1
#               Wholesale Club/Supercenter              1   1         1    1
#               Worship Facility                       17  17        17   17
#
# ...

# %%
primarygroup = df.groupby("PRIMARYPROPERTYTYPE_SELFSELECT")

# %%
# The property types self-selected by building owners are listed below.  Question for Power Rangers..
#Should we focus on property types with largerst counts?
for PRIMARYPROPERTYTYPE_SELFSELECT, PRIMARYPROPERTYTYPE_SELFSELECT_df in primarygroup:
    print(PRIMARYPROPERTYTYPE_SELFSELECT)
# Out:
# Adult Education
# Bank Branch
# Bank/Financial Institution
# College/University
# College/University (Campus-Level)
# Courthouse
# Data Center
# Distribution Center
# Drinking Water Treatment & Distribution
# Enclosed Mall
# Financial Office
# Fire Station
# Fitness Center/Health Club/Gym
# Food Sales
# Food Service
# Hospital (General Medical & Surgical)
# Hospital (General Medical and Surgical)
# Hotel
# K-12 School
# Laboratory
# Library
# Manufacturing/Industrial Plant
# Medical Office
# Mixed Use Property
# Movie Theater
# Multifamily Housing
# Museum
# Non-Refrigerated Warehouse
# Office
# Other
# Other - Education
# Other - Entertainment/Public Assembly
# Other - Lodging/Residential
# Other - Mall
# Other - Public Services
# Other - Recreation
# Other - Restaurant/Bar
# Other - Services
# Other - Specialty Hospital
# Other - Utility
# Other -Utility
# Other/Specialty Hospital
# Outpatient Rehabilitation/Physical Therapy
# Parking
# Performing Arts
# Police Station
# ...

# %%
#To begin some statistical analysis
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df.hist(column="REPORTINGYEAR")
"""TEST"""
# Out:
# 'TEST'

# %%
#Creates new dataframes to cull out data for 2018 and 2019.
df_report_year_2018 = df[(df['REPORTINGYEAR']== 2018)]
df_report_year_2019 = df[(df['REPORTINGYEAR']== 2019)]

# %%
#Simple histogram that shows energy star scores are skewed to the right.. to higher scores.
#Of note, the DC Dept of Energy and Environment indicates that scoring algorithum has changed between 2017 and 2018.
#Scores from 2017 and earlier cannot be compared to 2018 and later.
df.hist(column = "ENERGYSTARSCORE")
# Out:
# array([[<AxesSubplot:title={'center':'ENERGYSTARSCORE'}>]], dtype=object)

# %%
# Provides the basic statistics for all Energy Star Scores.  
print (df["ENERGYSTARSCORE"].describe())
# Out:
# count    9353.000000
# mean       61.519406
# std        27.508403
# min         1.000000
# 25%        42.000000
# 50%        68.000000
# 75%        83.000000
# max       100.000000
# Name: ENERGYSTARSCORE, dtype: float64

# %%
#Provides Energy Star Score stats for 2018.
print (df_report_year_2018["ENERGYSTARSCORE"].describe())
# Out:
# count    1663.000000
# mean       59.372820
# std        27.230827
# min         1.000000
# 25%        40.000000
# 50%        64.000000
# 75%        80.000000
# max       100.000000
# Name: ENERGYSTARSCORE, dtype: float64

# %%
#Describes Energy Star Score basic stats grouped by year.  Note how counts increase in later years.
#Of interest, Energy Star Scores are a bit higher overall in 2017 and earlier.
df.groupby(["REPORTINGYEAR"])[["ENERGYSTARSCORE"]].describe()
# Out:
#               ENERGYSTARSCORE                                                \
#                         count       mean        std  min    25%   50%   75%
# REPORTINGYEAR
# 2010                     41.0  66.536585  22.933706  1.0  54.00  78.0  83.0
# 2011                    315.0  63.288889  26.170601  1.0  48.00  74.0  82.0
# 2012                    430.0  62.958140  27.403114  1.0  49.00  73.0  83.0
# 2013                    738.0  56.836043  29.153018  1.0  33.25  63.0  81.0
# 2014                   1067.0  60.375820  28.749587  1.0  39.00  67.0  83.0
# 2015                   1162.0  62.814974  28.101165  1.0  42.00  71.0  85.0
# 2016                   1184.0  63.929899  27.214672  1.0  44.00  71.0  86.0
# 2017                   1235.0  64.057490  27.286447  1.0  43.00  72.0  86.0
# 2018                   1663.0  59.372820  27.230827  1.0  40.00  64.0  80.0
# 2019                   1518.0  61.104743  25.951813  1.0  42.00  66.0  81.0
#
#
#                  max
# REPORTINGYEAR
# ...

# %%
#Simple scatter plot shows there is some minor correlation between EUI and Energy Star Score, which is to be expected.
#Using an alpha of 0.2 eliminates some of the saturation.
w=df["SITEEUI_KBTU_FT"].quantile(0.98)
df_filtered=df[df["SITEEUI_KBTU_FT"]<w]
sns.scatterplot(data=df_filtered,x="ENERGYSTARSCORE",y="SITEEUI_KBTU_FT", alpha=0.2)
# Out:
# <AxesSubplot:xlabel='ENERGYSTARSCORE', ylabel='SITEEUI_KBTU_FT'>

# %%
#Using just data from 2018 provides about the same result.  
w=df["SITEEUI_KBTU_FT"].quantile(0.98)
df_filtered=df_report_year_2018[df["SITEEUI_KBTU_FT"]<w]
sns.scatterplot(data=df_filtered,x="ENERGYSTARSCORE",y="SITEEUI_KBTU_FT", alpha=0.2)
# Out:
# <ipython-input-43-e5fb7975e9c0>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_filtered=df_report_year_2018[df["SITEEUI_KBTU_FT"]<w]
# <AxesSubplot:xlabel='ENERGYSTARSCORE', ylabel='SITEEUI_KBTU_FT'>

# %%
#Also of interest is renewable energy.  Let's look at the variables basic statistics.
print (df["ELECTRICITYUSE_RENEWABLE_KWH"].describe())
# Out:
# count    1.297400e+04
# mean     6.018525e+04
# std      5.879481e+06
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      6.695953e+08
# Name: ELECTRICITYUSE_RENEWABLE_KWH, dtype: float64

# %%
#Looks like a lot of the fields contain 0...no renewable energy.  Let's clean up the column and drop those with 0s.
df_renewable = df[df["ELECTRICITYUSE_RENEWABLE_KWH"] > 0]
df_renewable.count()
print (df_renewable ["ELECTRICITYUSE_RENEWABLE_KWH"])
# Out:
# 43       107188.0
# 52       124622.0
# 65       310311.2
# 124      276909.0
# 130      539780.7
#            ...
# 15382    106487.3
# 15422    144143.0
# 15518     92714.5
# 15671    227820.0
# 15674    199734.5
# Name: ELECTRICITYUSE_RENEWABLE_KWH, Length: 282, dtype: float64

# %%
#now let's look at a plot of the renewable information as compared to Energy Star Scores.
sns.scatterplot(data=df_renewable,x="ENERGYSTARSCORE",y="ELECTRICITYUSE_RENEWABLE_KWH")
plt.ylim(0,1000000)
#Not seeing any correlation in the scatterplot. I don't believe the renewable energy information is useful and can 
#likely be excluded without concern.
# Out:
# (0.0, 1000000.0)

# %%
#Going back to building type, let's look more closely at counts by year.
ag = df.groupby("REPORTINGYEAR").PRIMARYPROPERTYTYPE_SELFSELECT.value_counts().sort_index()

# %%
print(ag)
# Out:
# REPORTINGYEAR  PRIMARYPROPERTYTYPE_SELFSELECT
# 2010           College/University                       10
#                College/University (Campus-Level)         4
#                Hospital (General Medical & Surgical)     1
#                Mixed Use Property                        1
#                Multifamily Housing                      15
#                                                         ..
# 2019           Supermarket/Grocery Store                15
#                Urgent Care/Clinic/Other Outpatient       2
#                Wastewater Treatment Plant                1
#                Wholesale Club/Supercenter                1
#                Worship Facility                         17
# Name: PRIMARYPROPERTYTYPE_SELFSELECT, Length: 412, dtype: int64

# %%
ag.unstack()
# Out:
# PRIMARYPROPERTYTYPE_SELFSELECT  Adult Education  Bank Branch  \
# REPORTINGYEAR
# 2010                                        NaN          NaN
# 2011                                        1.0          1.0
# 2012                                        1.0          1.0
# 2013                                        2.0          NaN
# 2014                                        2.0          NaN
# 2015                                        1.0          NaN
# 2016                                        1.0          NaN
# 2017                                        1.0          NaN
# 2018                                        4.0          NaN
# 2019                                        5.0          NaN
#
# PRIMARYPROPERTYTYPE_SELFSELECT  Bank/Financial Institution  \
# REPORTINGYEAR
# 2010                                                   NaN
# 2011                                                   1.0
# 2012                                                   1.0
# ...

# %%
#Now let's group by building type by year and display in a chart that displays all rows.
agf = df.groupby("PRIMARYPROPERTYTYPE_SELFSELECT").REPORTINGYEAR.value_counts().sort_index()

# %%
print(agf)
# Out:
# PRIMARYPROPERTYTYPE_SELFSELECT  REPORTINGYEAR
# Adult Education                 2011              1
#                                 2012              1
#                                 2013              2
#                                 2014              2
#                                 2015              1
#                                                  ..
# Worship Facility                2015             18
#                                 2016             19
#                                 2017             18
#                                 2018             22
#                                 2019             17
# Name: REPORTINGYEAR, Length: 412, dtype: int64

# %%
pd.set_option('display.max_rows', 500)

# %%
agf.unstack()
# This shows us where there are some inconsistenices.  For example, Fire Stations jump from 1 in 2017 to 14 in 2018 to 24 in 2019.
#This is likely due to a variation in classifying under "other" grouping, or changes in reporting status, eg. more fire stations reported.
#We can also see where the largest "type" categories of colleges/universities/K-12schools,hotels. multi-family houisng,offices and perhaps dormitories.
#Question to PowerRangers.. do we only focus on those categories with a large number of buildings?
# Out:
# REPORTINGYEAR                                     2010   2011   2012   2013  \
# PRIMARYPROPERTYTYPE_SELFSELECT
# Adult Education                                    NaN    1.0    1.0    2.0
# Bank Branch                                        NaN    1.0    1.0    NaN
# Bank/Financial Institution                         NaN    1.0    1.0    NaN
# College/University                                10.0   32.0   34.0   79.0
# College/University (Campus-Level)                  4.0   11.0   10.0    NaN
# Courthouse                                         NaN    NaN    NaN    NaN
# Data Center                                        NaN    1.0    1.0    1.0
# Distribution Center                                NaN    NaN    NaN    7.0
# Drinking Water Treatment & Distribution            NaN    NaN    NaN    NaN
# Enclosed Mall                                      NaN    NaN    NaN    1.0
# Financial Office                                   NaN    NaN    NaN    1.0
# ...

# %%
#This attempts to look at Site EUI by year and building type.  I am currently unable to figure out how to sort means while grouping by reporting year and builing type.
#tseui = df.groupby(["REPORTINGYEAR","PRIMARYPROPERTYTYPE_SELFSELECT"])["SITEEUI_KBTU_FT"].mean().sort_values(ascending = False)
tseui = df.groupby(["REPORTINGYEAR","PRIMARYPROPERTYTYPE_SELFSELECT"])["SITEEUI_KBTU_FT"].mean()
print(tseui)
# Out:
# REPORTINGYEAR  PRIMARYPROPERTYTYPE_SELFSELECT
# 2010           College/University                                     0.000000
#                College/University (Campus-Level)                     83.900000
#                Hospital (General Medical & Surgical)                  0.000000
#                Mixed Use Property                                     0.000000
#                Multifamily Housing                                   31.280000
#                Office                                                58.319231
#                Other                                                  6.550000
#                Residence Hall/Dormitory                              32.750000
# 2011           Adult Education                                       61.100000
#                Bank Branch                                           44.400000
#                Bank/Financial Institution                            40.200000
# ...

# %%
#officemean = df.groupby(["PRIMARYPROPERTYTYPE_SELFSELECT"]=="Office")["SITEEUI_KBTU_FT"].mean()
#print(officemean)

# %%
#See above.. not able to portray descending mean grouped by year and type.  Still working. 
#Below shows highest energy users, mean by property type by year(ungrouped).
df.groupby(["REPORTINGYEAR","PRIMARYPROPERTYTYPE_SELFSELECT"])["SITEEUI_KBTU_FT"].mean().sort_values(ascending = False)
# Out:
# REPORTINGYEAR  PRIMARYPROPERTYTYPE_SELFSELECT
# 2016           Wastewater Treatment Plant                          5059.200000
# 2015           K-12 School                                         1327.165574
#                Hotel                                               1172.121591
# 2016           Mixed Use Property                                  1108.614286
# 2014           K-12 School                                         1092.311475
# 2019           Drinking Water Treatment & Distribution              574.550000
# 2018           Drinking Water Treatment & Distribution              496.250000
#                Laboratory                                           455.950000
# 2011           Data Center                                          412.500000
# 2012           Data Center                                          402.400000
# 2011           Senior Care Community                                390.300000
# ...

# %%
pd.set_option('display.max_columns',80)

# %%
#Just checking to see where there are null values.
df.isnull().sum()
# Out:
# X                                     0
# Y                                     0
# OBJECTID                              0
# PID                                   0
# DCREALPROPERTYID                      0
# PMPROPERTYID                       2816
# PROPERTYNAME                       2919
# PMPARENTPROPERTYID                15032
# PARENTPROPERTYNAME                15032
# REPORTINGYEAR                         0
# REPORTSTATUS                          0
# ADDRESSOFRECORD                       3
# OWNEROFRECORD                         7
# WARD                                221
# REPORTEDADDRESS                    2919
# CITY                                  3
# STATE                                 3
# POSTALCODE                         2025
# YEARBUILT                           629
# PRIMARYPROPERTYTYPE_SELFSELECT     2919
# PRIMARYPROPERTYTYPE_EPACALC        3009
# TAXRECORDFLOORAREA                 2357
# REPORTEDBUILDINGGROSSFLOORAREA     2757
# ...

# %%
w=df["SITEEUI_KBTU_FT"].quantile(0.98)
df_filtered=df[df["SITEEUI_KBTU_FT"]<w]
sns.boxplot(y=df_filtered["SITEEUI_KBTU_FT"])
# Out:
# <AxesSubplot:ylabel='SITEEUI_KBTU_FT'>

# %%
#This shows there is no correlation between variables - energy usage and year built.
sns.scatterplot(data=df_filtered,x="SITEEUI_KBTU_FT",y="YEARBUILT", alpha=0.3)
# Out:
# <AxesSubplot:xlabel='SITEEUI_KBTU_FT', ylabel='YEARBUILT'>

# %%
sns.scatterplot(data=df_filtered,x="SITEEUI_KBTU_FT",y="WATERUSE_ALLWATERSOURCES_KGAL")
# Out:
# <AxesSubplot:xlabel='SITEEUI_KBTU_FT', ylabel='WATERUSE_ALLWATERSOURCES_KGAL'>

# %%
features1= list(["YEARBUILT","ENERGYSTARSCORE","SITEEUI_KBTU_FT","WEATHERNORMALZEDSITEEUI_KBTUFT","TOTGHGEMISSIONS_METRICTONSCO2E","WATERUSE_ALLWATERSOURCES_KGAL","ELECTRICITYUSE_RENEWABLE_KWH"])
corrMatrix=df[features1].corr()
sns.heatmap(corrMatrix, annot=True)
#not seeing much correclation between variables
# Out:
# <AxesSubplot:>

# %%
df["EUI_KBTUFT_JAN"]=df["ELECTRICITYUSE_KBTU_JANUARY"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]
df["EUI_KBTUFT_FEB"]=df["ELECTRICITYUSE_KBTU_FEBRUARY"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]
df["EUI_KBTUFT_MAR"]=df["ELECTRICITYUSE_KBTU_MARCH"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]
df["EUI_KBTUFT_APR"]=df["ELECTRICITYUSE_KBTU_APRIL"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]
df["EUI_KBTUFT_MAY"]=df["ELECTRICITYUSE_KBTU_MAY"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]
df["EUI_KBTUFT_JUN"]=df["ELECTRICITYUSE_KBTU_JUNE"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]
df["EUI_KBTUFT_JUL"]=df["ELECTRICITYUSE_KBTU_JULY"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]
df["EUI_KBTUFT_AUG"]=df["ELECTRICITYUSE_KBTU_AUGUST"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]
df["EUI_KBTUFT_SEP"]=df["ELECTRICITYUSE_KBTU_SEPTEMBER"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]
df["EUI_KBTUFT_OCT"]=df["ELECTRICITYUSE_KBTU_OCTOBER"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]
df["EUI_KBTUFT_NOV"]=df["ELECTRICITYUSE_KBTU_NOVEMBER"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]
df["EUI_KBTUFT_DEC"]=df["ELECTRICITYUSE_KBTU_DECEMBER"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]
df["GEUI_KBTUFT_JAN"]=df["NATURALGAS_KBTU_JANUARY"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]
df["GEUI_KBTUFT_FEB"]=df["NATURALGAS_KBTU_FEBRUARY"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]
df["GEUI_KBTUFT_MAR"]=df["NATURALGAS_KBTU_MARCH"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]
df["GEUI_KBTUFT_APR"]=df["NATURALGAS_KBTU_APRIL"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]
df["GEUI_KBTUFT_MAY"]=df["NATURALGAS_KBTU_MAY"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]
df["GEUI_KBTUFT_JUN"]=df["NATURALGAS_KBTU_JUNE"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]
df["GEUI_KBTUFT_JUL"]=df["NATURALGAS_KBTU_JULY"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]
df["GEUI_KBTUFT_AUG"]=df["NATURALGAS_KBTU_AUGUST"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]
df["GEUI_KBTUFT_SEP"]=df["NATURALGAS_KBTU_SEPTEMBER"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]
df["GEUI_KBTUFT_OCT"]=df["NATURALGAS_KBTU_OCTOBER"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]
df["GEUI_KBTUFT_NOV"]=df["NATURALGAS_KBTU_NOVEMBER"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]
df["GEUI_KBTUFT_DEC"]=df["NATURALGAS_KBTU_DECEMBER"]/df["REPORTEDBUILDINGGROSSFLOORAREA"]

# %%
df.head
# Out:
# <bound method NDFrame.head of                X          Y  OBJECTID          PID DCREALPROPERTYID  \
# 0     -77.039745  38.895862         1    PM4373175        0171_0814
# 1     -77.016460  38.900567         2  DC0516S0036       0516S_0036
# 2     -77.037746  38.906498         3   DC01820082        0182_0082
# 3     -77.031592  38.902935         4    PM1331555        0248_0812
# 4     -77.043072  38.906668         5    PM3299991        0139_0817
# ...          ...        ...       ...          ...              ...
# 15726 -77.021657  38.907957     15727    PM3858763        0447_0039
# 15727 -77.002476  38.919533     15728    PM4380823        3560_0001
# 15728 -76.994290  38.922150     15729    PM4822871        3846_0085
# 15729 -76.998195  38.928182     15730    PM4373562        3648_0915
# 15730 -77.053795  38.928391     15731    PM3984618        2210_0010
#
#        PMPROPERTYID                              PROPERTYNAME  \
# ...

# %%
df["EUI_KBTUFT_JAN"].isnull().sum()
# Out:
# 3123

# %%
df["EUI_KBTUFT_FEB"].isnull().sum()
#Why are there 3,172 empty fields when initially analysis shows 2,831 empty for both variables?
# Out:
# 3123

# %%
df["EUI_KBTUFT_MAR"].isnull().sum()
# Out:
# 3123

# %%
df["GEUI_KBTUFT_JAN"].isnull().sum()
# Out:
# 3123
